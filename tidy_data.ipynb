# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pydataset import data

# %% [markdown]
# ### Attendance Data
#
# - Load the attendance.csv file and calculate an attendnace percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.

# %%
df_attendance = pd.read_csv("/Users/jaredvahle/CodeUp-Datascience/classification-exercises/untidy-data/attendance.csv")

# %%
df_attendance
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %%
df_attendance = df_attendance.rename(columns = {"Unnamed: 0":"name"})

# %%
df_attendance.head()
# Out:
#     name 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05 2018-01-06  \
# 0  Sally          P          T          T          H          P          A
# 1   Jane          A          P          T          T          T          T
# 2  Billy          A          T          A          A          H          T
# 3   John          P          T          H          P          P          T
#
#   2018-01-07 2018-01-08
# 0          T          T
# 1          A          T
# 2          P          T
# 3          P          P

# %%
df_attendance = df_attendance.melt(id_vars = "name", var_name = "date",value_name = "attendance")

# %%
df_attendance["attendance"] = df_attendance.attendance.replace(to_replace = ["A","H","T","P"],value = [0,.5,.9,1])

# %%
df_attendance
# Out:
#      name        date  attendance
# 0   Sally  2018-01-01         1.0
# 1    Jane  2018-01-01         0.0
# 2   Billy  2018-01-01         0.0
# 3    John  2018-01-01         1.0
# 4   Sally  2018-01-02         0.9
# 5    Jane  2018-01-02         1.0
# 6   Billy  2018-01-02         0.9
# 7    John  2018-01-02         0.9
# 8   Sally  2018-01-03         0.9
# 9    Jane  2018-01-03         0.9
# 10  Billy  2018-01-03         0.0
# 11   John  2018-01-03         0.5
# 12  Sally  2018-01-04         0.5
# 13   Jane  2018-01-04         0.9
# 14  Billy  2018-01-04         0.0
# 15   John  2018-01-04         1.0
# 16  Sally  2018-01-05         1.0
# 17   Jane  2018-01-05         0.9
# 18  Billy  2018-01-05         0.5
# 19   John  2018-01-05         1.0
# 20  Sally  2018-01-06         0.0
# 21   Jane  2018-01-06         0.9
# 22  Billy  2018-01-06         0.9
# 23   John  2018-01-06         0.9
# 24  Sally  2018-01-07         0.9
# 25   Jane  2018-01-07         0.0
# ...

# %%
df_attendance.groupby("name").attendance.mean()
# Out:
# name
# Billy    0.5250
# Jane     0.6875
# John     0.9125
# Sally    0.7625
# Name: attendance, dtype: float64

# %% [markdown]
# ### Coffee Levels
#
# >- a. Read the coffee_levels.csv file.
# >- b. Transform the data so that each carafe is in it's own column.
# >- c. Is this the best shape for the data?

# %%
df = pd.read_csv("/Users/jaredvahle/CodeUp-Datascience/classification-exercises/untidy-data/coffee_levels.csv")
df.head(20)
# Out:
#     hour coffee_carafe  coffee_amount
# 0      8             x       0.816164
# 1      9             x       0.451018
# 2     10             x       0.843279
# 3     11             x       0.335533
# 4     12             x       0.898291
# 5     13             x       0.310711
# 6     14             x       0.507288
# 7     15             x       0.215043
# 8     16             x       0.183891
# 9     17             x       0.391560
# 10     8             y       0.189297
# 11     9             y       0.521502
# 12    10             y       0.023163
# 13    11             y       0.235529
# 14    12             y       0.017009
# 15    13             y       0.997464
# 16    14             y       0.058361
# 17    15             y       0.144644
# 18    16             y       0.544676
# 19    17             y       0.594126

# %%
df_tidy = df.pivot_table(index = ["hour"],
                            columns = ["coffee_carafe"],
                            values = "coffee_amount").reset_index()
df_tidy
# Out:
# coffee_carafe  hour         x         y         z
# 0                 8  0.816164  0.189297  0.999264
# 1                 9  0.451018  0.521502  0.915990
# 2                10  0.843279  0.023163  0.144928
# 3                11  0.335533  0.235529  0.311495
# 4                12  0.898291  0.017009  0.771947
# 5                13  0.310711  0.997464  0.398520
# 6                14  0.507288  0.058361  0.864464
# 7                15  0.215043  0.144644  0.436364
# 8                16  0.183891  0.544676  0.280621
# 9                17  0.391560  0.594126  0.436677

# %%
# this is a good way to clean the data because it is very understandable to the eye,
# and you can grab the values very easily in the dataframe

# %% [markdown]
# ### Cake Recipes
#
# >- a. Read the cake_recipes.csv data. This data set contains cake tastiness scores for combinations of different recipes, oven rack positions, and oven temperatures.
# >- b. Tidy the data as necessary.
# >- c. Which recipe, on average, is the best? recipe b
# >- d. Which oven temperature, on average, produces the best results? 275
# >- e. Which combination of recipe, rack position, and temperature gives the best result? recipe b, bottom rack, 300 degrees

# %%
df_cake = pd.read_csv("/Users/jaredvahle/CodeUp-Datascience/classification-exercises/untidy-data/cake_recipes.csv")
df_cake.head()
# Out:
#   recipe:position        225        250        275        300
# 0        a:bottom  61.738655  53.912627  74.414730  98.786784
# 1           a:top  51.709751  52.009735  68.576858  50.228470
# 2        b:bottom  57.095320  61.904369  61.196980  99.248541
# 3           b:top  82.455004  95.224151  98.594881  58.169349
# 4        c:bottom  96.470207  52.001358  92.893227  65.473084

# %%
df_cake[["recipe","position"]] = df_cake["recipe:position"].str.split(":",expand = True)
df_cake.drop(columns = "recipe:position",inplace = True)

# %%
df_cake = df_cake.melt(id_vars = ["recipe","position"],var_name = "temp",value_name = "score")
df_cake
# Out:
#    recipe position temp      score
# 0       a   bottom  225  61.738655
# 1       a      top  225  51.709751
# 2       b   bottom  225  57.095320
# 3       b      top  225  82.455004
# 4       c   bottom  225  96.470207
# 5       c      top  225  71.306308
# 6       d   bottom  225  52.799753
# 7       d      top  225  96.873178
# 8       a   bottom  250  53.912627
# 9       a      top  250  52.009735
# 10      b   bottom  250  61.904369
# 11      b      top  250  95.224151
# 12      c   bottom  250  52.001358
# 13      c      top  250  82.795477
# 14      d   bottom  250  58.670419
# 15      d      top  250  76.101363
# 16      a   bottom  275  74.414730
# 17      a      top  275  68.576858
# 18      b   bottom  275  61.196980
# 19      b      top  275  98.594881
# 20      c   bottom  275  92.893227
# 21      c      top  275  92.098049
# 22      d   bottom  275  51.747686
# 23      d      top  275  59.571620
# 24      a   bottom  300  98.786784
# 25      a      top  300  50.228470
# ...

# %%
df_cake.groupby("recipe").score.mean()
#The best recipe is B
# Out:
# recipe
# a    63.922201
# b    76.736074
# c    75.874748
# d    62.864844
# Name: score, dtype: float64

# %%
df_cake.groupby("temp").score.mean()
#The best temp is 275
# Out:
# temp
# 225    71.306022
# 250    66.577437
# 275    74.886754
# 300    66.627655
# Name: score, dtype: float64

# %%
position = df_cake.score.idxmax()

# %%
df_cake.iloc[position]
# Out:
# recipe              b
# position       bottom
# temp              300
# score       99.248541
# Name: 26, dtype: object
